# %% [markdown]
# # Assignment P1: Clustering

# %% [markdown]
# In this assignment, we will load the in-built `USArrests` to perform clustering

# %% [markdown]
# ### Loading the `USArrests` dataset into variable `df`

# %%
df<-USArrests

# %%
head(df)
# Out:
#            Murder Assault UrbanPop Rape
# Alabama    13.2   236     58       21.2
# Alaska     10.0   263     48       44.5
# Arizona     8.1   294     80       31.0
# Arkansas    8.8   190     50       19.5
# California  9.0   276     91       40.6
# Colorado    7.9   204     78       38.7

# %% [markdown]
# Now, we will perform cluster analysis using Hierarchical clustering to determine the value of k(number of clusters) for K-Means clustering

# %% [markdown]
# ### Distance Matrix Calculation

# %%
state_dm<-dist(df)

# %% [markdown]
# ###  Hierarchical Clustering

# %%
hir_clust<-hclust(state_dm,method = "complete")

# %%
hir_clust
# Out:
# Call:
# hclust(d = state_dm, method = "complete")
#
# Cluster method   : complete
# Distance         : euclidean
# Number of objects: 50

# %%
plot(hir_clust,labels = rownames(df), ylab = "Distance")
# Out:
# Plot with title “Cluster Dendrogram”

# %%
plot(hir_clust,labels = rownames(df), ylab = "Distance")
abline(h=200, col="red", lwd=2) 
abline(h=150, col="blue", lwd=2)
rect.hclust(hir_clust, k=3)
# Out:
# Plot with title “Cluster Dendrogram”

# %%
set.seed(1234)
library(cluster)
kmeans_clust<-kmeans(df,centers = 3, nstart = 20)

# %%
kmeans_clust$centers
# Out:
#   Murder    Assault  UrbanPop Rape
# 1  8.214286 173.2857 70.64286 22.84286
# 2  4.270000  87.5500 59.75000 14.39000
# 3 11.812500 272.5625 68.31250 28.37500

# %%
y_kmeans <- kmeans_clust$cluster
clusplot(df[, c("Murder","Assault")],
y_kmeans,lines = 0,shade = TRUE, color = TRUE,labels = 2,
plotchar = FALSE, span = TRUE,
main = paste("Cluster US States Based on Arrest Data"),
xlab = 'Murder',
ylab = 'Assault')
# Out:
# Plot with title “Cluster US States Based on Arrest Data”

# %%
df$cluster<-kmeans_clust$cluster

# %%
head(df)
# Out:
#            Murder Assault UrbanPop Rape cluster
# Alabama    13.2   236     58       21.2 3
# Alaska     10.0   263     48       44.5 3
# Arizona     8.1   294     80       31.0 3
# Arkansas    8.8   190     50       19.5 1
# California  9.0   276     91       40.6 3
# Colorado    7.9   204     78       38.7 1
